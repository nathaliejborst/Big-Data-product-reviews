# %%
import pandas as pd

# %%
df_1 = pd.read_csv('reviews/train-1.csv')

# %%
df_1.columns
df_1.drop(columns=['Unnamed: 0'],inplace=True) # drop index column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/50/_t50pc954ds6ks2d44n1mqs40000gn/T/ipykernel_67191/3715357511.py in <module>
#       1 df_1.columns
# ----> 2 df_1.drop(columns=['Unnamed: 0'],inplace=True) # drop index column
#       3 df_1['product_id'].duplicated()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
# check id there are duplicates in product ID's
df_1['product_id'].duplicated().value_counts()
dupl_productids = df_1[df_1['product_id'].duplicated()]
dupl_productids
# Out:
#       product_id  product_parent  \
# 72    B008D30K7E       122923011
# 171   B004NDRIXW       934394072
# 306   B008D30K7E       122923011
# 333   B0039P1O4O       903886762
# 345   B00JKGYV6E       657404229
# ...          ...             ...
# 1157  B0000DKKY4       537777474
# 1163  B00DJFIMW6       271429756
# 1167  B00NOPQU2K       627793267
# 1182  B0042HOU1W       120788586
# 1184  B004LRO176       169791471
#
#                                           product_title vine  \
# 72    Hundred-Year-Old Man Who Climbed Out of the Wi...    N
# 171              Steven R. Monroes I spit on your Grave    N
# 306   Hundred-Year-Old Man Who Climbed Out of the Wi...    N
# 333                   Kit mains libres Supertooth Buddy    N
# 345                                                   X    N
# ...                                                 ...  ...
# 1157                       The Very Best Of Cat Stevens    N
# 1163         Minion Rush: Ich - Einfach unverbesserlich    N
# ...
